# %%
import re
import sys

pnum = 191
outf = open('warnindtmp.txt','w')
pref1 = '/Users/gcrane/Downloads/warner09a/shahnama09firduoft_0'
pref2 = '/Users/gcrane/Downloads/warner09/shahnama09firduoft_0'
for i in range(213,426):
    print('<pb n="' + str(pnum) + '"/>"',file=outf)
    pnum = pnum + 1

    fname = pref1 + str(i) + '.txt'
    f = open(fname)
    for l in f:
        print(l,end='',file=outf)
    f.close()

    fname = pref2 + str(i) + '.txt'
    f = open(fname)
    for l in f:
        print(l,end='',file=outf)
    f.close()

    print(fname,i)
# Out:
# /Users/gcrane/Downloads/warner09/shahnama09firduoft_0213.txt 213
# /Users/gcrane/Downloads/warner09/shahnama09firduoft_0214.txt 214
# /Users/gcrane/Downloads/warner09/shahnama09firduoft_0215.txt 215
# /Users/gcrane/Downloads/warner09/shahnama09firduoft_0216.txt 216
# /Users/gcrane/Downloads/warner09/shahnama09firduoft_0217.txt 217
# /Users/gcrane/Downloads/warner09/shahnama09firduoft_0218.txt 218
# /Users/gcrane/Downloads/warner09/shahnama09firduoft_0219.txt 219
# /Users/gcrane/Downloads/warner09/shahnama09firduoft_0220.txt 220
# /Users/gcrane/Downloads/warner09/shahnama09firduoft_0221.txt 221
# /Users/gcrane/Downloads/warner09/shahnama09firduoft_0222.txt 222
# /Users/gcrane/Downloads/warner09/shahnama09firduoft_0223.txt 223
# /Users/gcrane/Downloads/warner09/shahnama09firduoft_0224.txt 224
# /Users/gcrane/Downloads/warner09/shahnama09firduoft_0225.txt 225
# /Users/gcrane/Downloads/warner09/shahnama09firduoft_0226.txt 226
# ...
