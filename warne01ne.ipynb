# %%
import re
import sys

f = open('shahnameh-warn02.xml')

persns = {}
placens = {}
rs = {}
types = {}
for l in f:
    #print(l)
    while(re.search('<persName>([A-Z][^<]+)',l)):
        #print(l,end='')
        m = re.search('<persName>([A-Z][^<]+)',l)
        if(m):
            curpn = m[1]
           # print(curpn,l,end='')
            if( not curpn in persns):
                persns[curpn] = 1
            else:
                persns[curpn] =  persns[curpn] + 1
        l = re.sub('<persName>([A-Z][^<]+)','',l,1)

    while(re.search('<rs type="([^"]+)">([A-Z][^<]+)',l)):
        #print(l,end='')
        m = re.search('<rs type="([^"]+)">([A-Z][^<]+)',l)
        if(m):
            curpn = m[2]
            curtype = m[1]
           # print(curpn,l,end='')
            if( not curpn in rs):
                rs[curpn] = 1
            else:
                rs[curpn] =  rs[curpn] + 1
            if( not curtype in types):
                types[curpn] = curtype
            else:
                types[curtype] = types[curtype] + 1
        l = re.sub('<rs type="([^"]+)">([A-Z][^<]+)','',l,1)

        
    while(re.search('<placeName>([A-Z][^<]+)',l)):
        #print(l,end='')
        m = re.search('<placeName>([A-Z][^<]+)',l)
        if(m):
            curpn = m[1]
           # print(curpn,l,end='')
            if( not curpn in placens):
                placens[curpn] = 1
            else:
                placens[curpn] =  placens[curpn] + 1
        l = re.sub('<placeName>([A-Z][^<]+)','',l,1)
savel = l
    #print(l,end='')

    
f.close()


f = open('shahnameh.warn01.xml')

persns = {}
placens = {}
rs = {}
types = {}
for l in f:
    #print(l)
    while(re.search('<persName>([A-Z][^<]+)',l)):
        #print(l,end='')
        m = re.search('<persName>([A-Z][^<]+)',l)
        if(m):
            curpn = m[1]
           # print(curpn,l,end='')
            if( not curpn in persns):
                persns[curpn] = 1
            else:
                persns[curpn] =  persns[curpn] + 1
        l = re.sub('<persName>([A-Z][^<]+)','',l,1)

    while(re.search('<rs type="([^"]+)">([A-Z][^<]+)',l)):
        #print(l,end='')
        m = re.search('<rs type="([^"]+)">([A-Z][^<]+)',l)
        if(m):
            curpn = m[2]
            curtype = m[1]
           # print(curpn,l,end='')
            if( not curpn in rs):
                rs[curpn] = 1
            else:
                rs[curpn] =  rs[curpn] + 1
            if( not curtype in types):
                types[curpn] = curtype
            else:
                types[curtype] = types[curtype] + 1
        l = re.sub('<rs type="([^"]+)">([A-Z][^<]+)','',l,1)

        
    while(re.search('<placeName>([A-Z][^<]+)',l)):
        #print(l,end='')
        m = re.search('<placeName>([A-Z][^<]+)',l)
        if(m):
            curpn = m[1]
           # print(curpn,l,end='')
            if( not curpn in placens):
                placens[curpn] = 1
            else:
                placens[curpn] =  placens[curpn] + 1
        l = re.sub('<placeName>([A-Z][^<]+)','',l,1)
savel = l
    #print(l,end='')

    
f.close()


persns['Abtin'] = 1
persns['Arnawaz'] = 1
persns['Barman'] = 1

persns['Dakiki'] = 1


persns['Faranak'] = 1
persns['Faridun'] = 1

persns['Gaiumart'] = 1
persns['Jandal'] = 1


persns['Kakwi'] = 1
persns['Khazarwan'] = 1

persns['Keresaspa'] = 1


persns['Manu'] = 1

persns['Sarv'] = 1
persns['Shahrinaz'] = 1

persns['Shirwi'] = 1

persns['Siyamak'] = 1

persns['Sindukht'] = 1
persns['Surtish'] = 1


persns['Taliman'] = 1
persns['Traitana'] = 1
persns['Trita'] = 1

persns['Zadsham'] = 1
persns['Zoroaster'] = 1

persns['Giv'] = 142
persns['Bizhan'] = 116
persns['Khusrau'] = 110
persns['Piran'] = 88

rs['Khan'] = 73
types['Khan'] = 'role'

persns['Gudarz'] = 72
persns['Siyawush'] = 67
persns['Fariburz'] = 46
persns['Bahram'] = 40
persns['Farud'] = 37
persns['Gurgin'] = 35
persns['Kamus'] = 35
persns['Rustam'] = 33
persns['Puladwand'] = 28
persns['Kaus'] = 27
persns['Human'] = 26
persns['Rivniz'] = 18
persns['Tazhav'] = 18
persns['Ruhham'] = 18
rs['Akwan'] = 16
types['Akwan'] = 'divinity'
persns['Mount'] = 16
persns['Tukhar'] = 15


placens['Dahistan'] = 1
placens['Damawand'] = 1
placens['Hamawan'] = 1

placens['Hindustan'] = 1

placens['Ind'] = 1
placens['Kannuj'] = 1

placens['Sari'] = 1

placens['Sipand'] = 1
placens['Tammisha'] = 1

placens['Yima'] = 1
placens['Zabul'] = 1
placens['Zabulistan'] = 1


rs['Ahrimans'] = 1
types['Ahrimans'] = 'divinity'


rs['Arabic'] = 1
types['Arabic'] = 'ethnic'

rs['Aryan'] = 1
types['Aryan'] = 'ethnic'

rs['Birmaya'] = 1
types['Birmaya'] = 'mythologicalcreature'

rs['Bundahish'] = 1
types['Bundahish'] = 'mythologicalcreature'



rs['Christian'] = 1
types['Christian'] = 'religion'


rs['Dahak'] = 1
types['Dahak'] = 'mythologicalcreature'

rs['Gandarep'] = 1
types['Gandarep'] = 'mythologicalcreature'

rs['Haoma'] = 1
types['Haoma'] = 'potion'

rs['Indian'] = 1
types['Indian'] = 'ethnic'

rs['Indians'] = 1
types['Indians'] = 'ethnic'

rs['Iranian'] = 1
types['Iranian'] = 'ethnic'

rs['Iranians'] = 1
types['Iranians'] = 'ethnic'


rs['Farwardin'] = 1
types['Farwardin'] = 'month'

rs['Mihr'] = 1
types['Mihr'] = 'month'


rs['Kuran'] = 1
types['Kuran'] = 'title'

rs['Pahlavi'] = 1
types['Pahlavi'] = 'language'

rs['Persian'] = 1
types['Persian'] = 'ethnic'


rs['Persians'] = 1
types['Persians'] = 'ethnic'

rs['Shah'] = 1
types['Shah'] = 'role'

rs['Shahs'] = 1
types['Shahs'] = 'role'



rs['Shahnama'] = 1
types['Shahnama'] = 'title'

rs['Simurgh'] = 1
types['Simurgh'] = 'title'


rs['Turanian'] = 1
types['Turanian'] = 'ethnic'

rs['Turanians'] = 1
types['Turanians'] = 'ethnic'

rs['Vedas'] = 1
types['Vedas'] = 'title'

rs['Zandavasta'] = 1
types['Zandavasta'] = 'title'


rs['Zoroastrian'] = 1
types['Zoroastrian'] = 'religion'



#for foo in rs:
#    print(foo,rs[foo])

# %%
outf = open('warn3xtmp.xml','w')
f = open('warn3tmp.xml')


for l in f:
    workl = l
    workl = re.sub('<[^>]+>',' ',l)
    workl = re.sub('[\.;,:?!\'\n\—\(\)’]',' ',workl)
    words = workl.split(' ')
    
    sawwords = {}
    for foo in words:
        if( foo in sawwords):
            continue
        sawwords[foo] = 1
        #print('sub',foo,l,end='')
        if( foo in persns):
            l = re.sub('\\b'+foo+'\\b','<persName>'+foo+'</persName>',l)
        if( foo in placens):
            l = re.sub('\\b'+foo+'\\b','<placeName>'+foo+'</placeName>',l)
        if( foo in rs):
            l = re.sub('\\b'+foo+'\\b','<rs type="' + types[foo] + '">'+foo+'</rs>',l)
  
            #print(foo,l,end='')
    l = re.sub('(Mount )(<placeName>)','\g<2>\g<1>',l)
    l = re.sub('(Kai )(<persName>)','\g<2>\g<1>',l)
    l = re.sub('(\')(<persName>)(A)','\g<2>\g<1>\g<3>',l)
    l = re.sub('(the Prophet)','<persName n="Mohammed">\g<1></persName>',l)
    l = re.sub('(the Black\s+)(<rs type="divinity">)','\g<2>\g<1>',l)
    
    print(l,end='',file=outf)
f.close()
outf.close()

untagged = {}
f = open('warn3xtmp.xml')
for l in f:
    l = re.sub('<placeName>[^<]+</placeName>',' ',l)
    l = re.sub('<persName>[^<]+</persName>',' ',l)
    l = re.sub('<rs[^>]+>[^<]+</rs>',' ',l)
    while(re.search('[a-z]\s+([A-Z][A-Za-z]+)',l)):
        m = re.search('[a-z]\s+([A-Z][A-Za-z]+)',l)
        curne = m[1]
        if( curne in untagged):
            untagged[curne] = 1 + untagged[curne]
        else:
            untagged[curne] = 1
        l = re.sub('[a-z]\s+([A-Z][A-Za-z]+)',' ',l)

f.close()
for foo in sorted(untagged, key=untagged.get,reverse=True):
    print(foo,untagged[foo])
    #print(foo)
print('done')
# Out:
# God 89
# Lion 33
# Lions 19
# Maker 19
# Sol 17
# Manizha 14
# Lord 14
# Him 13
# Kashan 13
# Zarasp 12
# Elephant 12
# Almighty 12
# Vol 11
# Farfburz 11
# Kalat 10
# Tree 10
# He 10
# Crocodile 10
# Gotarzes 9
# Milad 9
# His 9
# Shahd 9
# Shangul 9
# Zanga 8
# Judge 8
# Wayside 8
# Inn 8
# Sapad 8
# Ashkabus 8
# Paradise 7
# Kaian 7
# Kasa 7
# Prelude 6
# Faramarz 6
# Ashkash 6
# Charam 6
# Saklab 6
# Shida 6
# Part 5
# Parthian 5
# Cypress 5
# Kabuda 5
# All 5
# Riman 5
# Doomsday 5
# Farshidward 5
# Farangis 5
# Tidings 5
# Manshur 5
# Rustain 5
# Sigz 5
# Kamius 5
# Shakn 5
# Chingish 5
# Idol 5
# Irman 5
# Farhad 4
# Tazhiv 4
# Kai 4
# New 4
# Year 4
# Mayam 4
# Palashan 4
# Arzhang 4
# Nastihan 4
# Elephants 4
# Gudarzians 4
# Thee 4
# Master 4
# Himan 4
# Rim 4
# Fartus 4
# Counsel 4
# Kimus 4
# Mohl 4
# Kafur 4
# Thou 4
# Letter 4
# Piladwand 4
# Kaians 4
# English 3
# University 3
# III 3
# Ispanwi 3
# Lidan 3
# Guidarz 3
# Lustre 3
# Kat 3
# Farudun 3
# Tis 3
# ...
